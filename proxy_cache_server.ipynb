# %%
import import_ipynb
from proxy_cache import *
import socket
import sys
import _thread
import datetime
import os
import pickle
# Out:
# importing Jupyter notebook from proxy_cache.ipynb

# %%
cache = LinkedListCache(3);


def cache_fn(messageString, client_socket):
    
    print('Connected Accepted')
    
    HttpTypeMethod = messageString[0]
    URLpath = messageString[1]
    URLpath = URLpath[7:]
    
    
    print("Request is ", HttpTypeMethod, " to URL : ", URLpath)
    print("--------------------------------------------------")
    
    
    start = datetime.datetime.now()
    current_file = "/" + URLpath + ".txt"
    print(current_file[1:])
    try:
        #Search in the cache file
        file = open(current_file[1:], "r")
        contents = file.readlines()
        print("Match found in cache and reading the file\n")
        
        cache.insertItem(URLpath)
        print_cache(cache)
        
        for i in range(0, len(contents)):
            client_socket.send(contents[i].encode())
            
        print("Time taken to read from Cache:",datetime.datetime.now() - start , " Secs")
    
    except IOError:
        #Fetch from the main server at port 80
        start = datetime.datetime.now()
        print("Cache File not Found\n File is being fetched from Server to Create Cache\n")
       
        Proxy_server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        host_url = URLpath
        print(host_url)
        try:
            Proxy_server.connect((host_url, 80))
            cache.insertItem(URLpath)
            save_object(cache)
            print_cache(cache)
            print("Socket Connected on default Port 80 to fetch")
            ser_cache_file = Proxy_server.makefile('rwb', 0)
            
            ser_cache_file.write(bytes("GET " + "/ HTTP/1.1\r\nHost:"+ URLpath +"\r\n\r\n",encoding='utf8'))           
            br = ser_cache_file.readlines()
            
            print(br)
            temp = open("./" + URLpath +'.txt', "w")
      
            for dt in br:
                temp.write(str(dt))
                client_socket.send(bytes(str(dt),encoding='utf-8'))
            
        except:
            print("Not a  Valid URL/ Data Could not be written to file")
        print("Time taken to read from Server:",datetime.datetime.now() - start," Secs")
    print('Written data to file')
    client_socket.close()

def save_object(obj):
    try:
        os.remove('cache.pkl')
        # print("try save")
    except:
        print("Creating cache file")
        # print("except save")
    with open('cache.pkl', 'wb') as output:
            pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)


def main():
        try:
            global cache
            with open('cache.pkl', 'rb') as input:
                cache = pickle.load(input)
                print_cache(cache)
        except:
            print("Cache file doesn't exist. It is yet to be created")
        port_server = 8055
            
        server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        # server socket
        print("Server is started")
        server_socket.bind(('192.168.1.5', port_server))
        server_socket.listen(5)
        while True:
            print("Bind Successful")
            print("-------------------------------------")
            client_socket, addr = server_socket.accept() 
            print("Received Connection from <Host,Port> ", addr)
            message = client_socket.recv(5000).decode()
            messageString = str(message).split()
            if len(messageString) <= 1 or len(messageString) > 2:
                
                d = "HTTP/1.1 200 OK\r\n"
                d += "Content-Type: text/html; charset=utf-8\r\n"
                d += "\r\n"
                d += "<html><body>Hello World</body></html>\r\n\r\n"
                client_socket.sendall(d.encode())
                client_socket.shutdown(socket.SHUT_RDWR)
                continue
            
            _thread.start_new_thread(cache_fn ,(messageString, client_socket))
if __name__ == '__main__':
    main()
# Out:
# Cache file doesn't exist. It is yet to be created
# Server is started
# Bind Successful
# -------------------------------------
# Received Connection from <Host,Port>  ('192.168.1.5', 51333)
# Bind Successful
# -------------------------------------
# Connected Accepted
# Request is  GET  to URL :  www.facebook.com
# --------------------------------------------------
# www.facebook.com.txt
# Cache File not Found
#  File is being fetched from Server to Create Cache
#
# www.facebook.com
# Creating cache file
#
# Cache Item with frequency  1
# -----------------------------------------------
# www.facebook.com
# Socket Connected on default Port 80 to fetch
# Received Connection from <Host,Port>  ('192.168.1.5', 51335)
# Bind Successful
# -------------------------------------
# Connected Accepted
# Request is  GET  to URL :  www.facebook.com
# --------------------------------------------------
# www.facebook.com.txt
# Cache File not Found
#  File is being fetched from Server to Create Cache
#
# www.facebook.com
#
# Cache Item with frequency  2
# -----------------------------------------------
# www.facebook.com
# Socket Connected on default Port 80 to fetch
# Received Connection from <Host,Port>  ('192.168.1.5', 51338)
# Bind Successful
# -------------------------------------
# Connected Accepted
# Request is  GET  to URL :  www.instagram.com
# --------------------------------------------------
# www.instagram.com.txt
# Cache File not Found
#  File is being fetched from Server to Create Cache
#
# www.instagram.com
#
# Cache Item with frequency  2
# -----------------------------------------------
# www.facebook.com
#
# Cache Item with frequency  1
# -----------------------------------------------
# www.instagram.com
# Socket Connected on default Port 80 to fetch
# [b'HTTP/1.1 301 Moved Permanently\r\n', b'Location: https://www.facebook.com/\r\n', b'Content-Type: text/html; charset="utf-8"\r\n', b'X-FB-Debug: /47Dk3EvZMc0Dktj1b0Ww+TqbfnLzeozVQlkFTgQt7MXq+9lkFv0ueSIOLA5OCjjkb0iiDATTy25UnYQxvw0Tw==\r\n', b'Date: Mon, 22 Nov 2021 16:09:22 GMT\r\n', b'Priority: u=3,i\r\n', b'Alt-Svc: h3=":443"; ma=3600, h3-29=":443"; ma=3600\r\n', b'Connection: keep-alive\r\n', b'Content-Length: 0\r\n', b'\r\n']
# Time taken to read from Server: 0:03:05.317222  Secs
# Written data to file
# [b'HTTP/1.1 301 Moved Permanently\r\n', b'Location: https://www.facebook.com/\r\n', b'Content-Type: text/html; charset="utf-8"\r\n', b'X-FB-Debug: GOkAxz3N4HCnU1VikrthrOmBWw0VfiGocjOYw+ltog7ZvGDpjPKVoJJ8V1bDBcjszV0F3GY6bIT4dlOgq6OOHw==\r\n', b'Date: Mon, 22 Nov 2021 16:09:29 GMT\r\n', b'Alt-Svc: h3=":443"; ma=3600, h3-29=":443"; ma=3600\r\n', b'Connection: keep-alive\r\n', b'Content-Length: 0\r\n', b'\r\n']
# Time taken to read from Server: 0:03:05.099686  Secs
# Written data to file
# [b'HTTP/1.1 301 Moved Permanently\r\n', b'Location: https://www.instagram.com/\r\n', b'Content-Type: text/plain\r\n', b'Server: proxygen-bolt\r\n', b'X-FB-TRIP-ID: 1679558926\r\n', b'Alt-Svc: h3=":443"; ma=3600,h3-29=":443"; ma=3600\r\n', b'Date: Mon, 22 Nov 2021 16:09:43 GMT\r\n', b'Connection: keep-alive\r\n', b'Content-Length: 0\r\n', b'\r\n']
# Time taken to read from Server: 0:03:05.128132  Secs
# Written data to file

# %%
cache = LinkedListCache(3);


def cache_fn(messageString, client_socket):
    
    print('Connected Accepted')
    
    HttpTypeMethod = messageString[0]
    URLpath = messageString[1]
    URLpath = URLpath[7:]
    
    
    print("Request is ", HttpTypeMethod, " to URL : ", URLpath)
    print("--------------------------------------------------")
    
    
    start = datetime.datetime.now()
    current_file = "/" + URLpath + ".txt"
    print(current_file[1:])
    try:
        #Search in the cache file
        file = open(current_file[1:], "r")
        contents = file.readlines()
        print("Match found in cache and reading the file\n")
        
        cache.insertItem(URLpath)
        print_cache(cache)
        
        for i in range(0, len(contents)):
            client_socket.send(contents[i].encode())
            
        print("Time taken to read from Cache:",datetime.datetime.now() - start , " Secs")
    
    except IOError:
        #Fetch from the main server at port 80
        start = datetime.datetime.now()
        print("Cache File not Found\n File is being fetched from Server to Create Cache\n")
       
        Proxy_server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        host_url = URLpath
        print(host_url)
        try:
            Proxy_server.connect((host_url, 80))
            cache.insertItem(URLpath)
            save_object(cache)
            print_cache(cache)
            print("Socket Connected on default Port 80 to fetch")
            ser_cache_file = Proxy_server.makefile('rwb', 0)
            
            ser_cache_file.write(bytes("GET " + "/ HTTP/1.1\r\nHost:"+ URLpath +"\r\n\r\n",encoding='utf8'))           
            br = ser_cache_file.readlines()
            
            print(br)
            temp = open("./" + URLpath +'.txt', "w")
      
            for dt in br:
                temp.write(str(dt))
                client_socket.send(bytes(str(dt),encoding='utf-8'))
            
        except:
            print("Not a  Valid URL/ Data Could not be written to file")
        print("Time taken to read from Server:",datetime.datetime.now() - start," Secs")
    print('Written data to file')
    client_socket.close()

def save_object(obj):
    try:
        os.remove('cache2.pkl')
        # print("try save")
    except:
        print("Creating cache file")
        # print("except save")
    with open('cache2.pkl', 'wb') as output:
            pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)


def main():
        try:
            global cache
            with open('cache2.pkl', 'rb') as input:
                cache = pickle.load(input)
                print_cache(cache)
        except:
            print("Cache file doesn't exist. It is yet to be created")
        port_server = 8055
            
        server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        # server socket
        print("Server is started")
        server_socket.bind(('192.168.1.5', port_server))
        server_socket.listen(5)
        while True:
            print("Bind Successful")
            print("-------------------------------------")
            client_socket, addr = server_socket.accept() 
            print("Received Connection from <Host,Port> ", addr)
            message = client_socket.recv(5000).decode()
            messageString = str(message).split()
            if len(messageString) <= 1 or len(messageString) > 2:
                
                d = "HTTP/1.1 200 OK\r\n"
                d += "Content-Type: text/html; charset=utf-8\r\n"
                d += "\r\n"
                d += "<html><body>Hello World</body></html>\r\n\r\n"
                client_socket.sendall(d.encode())
                client_socket.shutdown(socket.SHUT_RDWR)
                continue
            
            _thread.start_new_thread(cache_fn ,(messageString, client_socket))
if __name__ == '__main__':
    main()
# Out:
# Cache file doesn't exist. It is yet to be created
# Server is started
# Bind Successful
# -------------------------------------
# Received Connection from <Host,Port>  ('192.168.1.5', 51563)
# Bind Successful
# -------------------------------------
# Connected Accepted
# Request is  GET  to URL :  www.facebook.com
# --------------------------------------------------
# www.facebook.com.txt
# Match found in cache and reading the file
#
#
# Cache Item with frequency  1
# -----------------------------------------------
# www.facebook.com
# Time taken to read from Cache: 0:00:00.014739  Secs
# Written data to file
# Received Connection from <Host,Port>  ('192.168.1.5', 51564)
# Bind Successful
# -------------------------------------
# Connected Accepted
# Request is  GET  to URL :  www.facebook.com
# --------------------------------------------------
# www.facebook.com.txt
# Match found in cache and reading the file
#
#
# Cache Item with frequency  2
# -----------------------------------------------
# www.facebook.com
# Time taken to read from Cache: 0:00:00.000699  Secs
# Written data to file
# Received Connection from <Host,Port>  ('192.168.1.5', 51569)
# Bind Successful
# -------------------------------------
# Connected Accepted
# Request is  GET  to URL :  www.instagram.com
# --------------------------------------------------
# www.instagram.com.txt
# Match found in cache and reading the file
#
#
# Cache Item with frequency  2
# -----------------------------------------------
# www.facebook.com
#
# Cache Item with frequency  1
# -----------------------------------------------
# www.instagram.com
# Time taken to read from Cache: 0:00:00.010913  Secs
# Written data to file
